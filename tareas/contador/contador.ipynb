# %%
# python notebook for Make Your Own Neural Network
# code for a 3-layer neural network, and code for learning the MNIST dataset
# (c) Tariq Rashid, 2016
# license is GPLv2

# %%
import numpy
# scipy.special for the sigmoid function expit()
import scipy.special
# library for plotting arrays
import matplotlib.pyplot
# ensure the plots are inside this notebook, not an external window
# %matplotlib inline

# %%
# neural network class definition
class neuralNetwork:

    
    # initialise the neural network
    def __init__(self, inputnodes, hiddennodes, outputnodes, learningrate):
        # set number of nodes in each input, hidden, output layer
        self.inodes = inputnodes
        self.hnodes = hiddennodes
        self.onodes = outputnodes
        
        # link weight matrices, wih and who
        # weights inside the arrays are w_i_j, where link is from node i to node j in the next layer
        # w11 w21
        # w12 w22 etc 
        self.wih = numpy.random.normal(0.0, pow(self.inodes, -0.5), (self.hnodes, self.inodes))
        self.who = numpy.random.normal(0.0, pow(self.hnodes, -0.5), (self.onodes, self.hnodes))

        # learning rate
        self.lr = learningrate
        
        # activation function is the sigmoid function
        self.activation_function = lambda x: scipy.special.expit(x)
        print("end init.")
        pass

    
    # train the neural network
    def train(self, inputs_list, targets_list):
        # convert inputs list to 2d array
        inputs = numpy.array(inputs_list, ndmin=2).T
        targets = numpy.array(targets_list, ndmin=2).T
        print("inputs")
        print(inputs)
        print("targets")
        print(targets)
        
        # calculate signals into hidden layer
        hidden_inputs = numpy.dot(self.wih, inputs)
        # calculate the signals emerging from hidden layer
        hidden_outputs = self.activation_function(hidden_inputs)
        print("Se realizó multiplicación de matrices y función de activación de hidden")
        # calculate signals into final output layer
        final_inputs = numpy.dot(self.who, hidden_outputs)
        # calculate the signals emerging from final output layer
        final_outputs = self.activation_function(final_inputs)
        print("Se realizó multiplicación de matrices y función de activación de final")
        print(final_outputs)
        # output layer error is the (target - actual)
        output_errors = targets - final_outputs
        print("El error es: "+str(output_errors))
        # hidden layer error is the output_errors, split by weights, recombined at hidden nodes
        hidden_errors = numpy.dot(self.who.T, output_errors) 
        
        # update the weights for the links between the hidden and output layers
        self.who += self.lr * numpy.dot((output_errors * final_outputs * (1.0 - final_outputs)), numpy.transpose(hidden_outputs))
        
        # update the weights for the links between the input and hidden layers
        self.wih += self.lr * numpy.dot((hidden_errors * hidden_outputs * (1.0 - hidden_outputs)), numpy.transpose(inputs))
        print("end train.")
        pass

    
    # query the neural network
    def query(self, inputs_list):
        # convert inputs list to 2d array
        inputs = numpy.array(inputs_list, ndmin=2).T
        
        # calculate signals into hidden layer
        hidden_inputs = numpy.dot(self.wih, inputs)
        # calculate the signals emerging from hidden layer
        hidden_outputs = self.activation_function(hidden_inputs)
        
        # calculate signals into final output layer
        final_inputs = numpy.dot(self.who, hidden_outputs)
        # calculate the signals emerging from final output layer
        final_outputs = self.activation_function(final_inputs)
        print("end query.")
        return final_outputs

# %%
# number of input, hidden and output nodes
input_nodes = 3
hidden_nodes = 3
output_nodes = 3

# learning rate
learning_rate = 0.1

print("# of input nodes: "+str(input_nodes)+"\n# of hidden nodes: "+str(hidden_nodes)+"\n# of output nodes: "+str(output_nodes))
# create instance of neural network
n = neuralNetwork(input_nodes,hidden_nodes,output_nodes, learning_rate)
print("The neural network was created")
# Out:
# # of input nodes: 3
# # of hidden nodes: 3
# # of output nodes: 3
# end init.
# The neural network was created

# %%
# load the mnist training data CSV file into a list
training_data_file = open("mnist_dataset/contador.csv", 'r')
training_data_list = training_data_file.readlines()
training_data_file.close()

# %%
# train the neural network

# epochs is the number of times the training data set is used for training
epochs = 150

for e in range(epochs):
    # go through all records in the training data set
    contador = 1
    for record in training_data_list:
        # split the record by the ',' commas
        all_values = record.split(',')
        # scale and shift the inputs
        inputs = (numpy.asfarray(all_values[0:3]) / 1.0) + 0.00
        # inputs = (numpy.asfarray(all_values[0:3]) / 255.0 * 0.99) + 0.01
        # create the target output values (all 0.01, except the desired label which is 0.99)
        # targets = numpy.zeros(output_nodes) + 0.01
        target_values = training_data_list[contador].split(',')
        targets = (numpy.asfarray(target_values[0:3]) / 1.0) + 0.00
        print("inputs ", inputs)
        print("targets ", targets)
        # all_values[0] is the target label for this record
        # targets[int(all_values[0])] = 0.99
        n.train(inputs, targets)
        contador += 1
        if(contador == 8):
            contador = 0
    pass
# Out:
# inputs  [ 0.  0.  0.]
# targets  [ 0.  0.  1.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.4735653 ]
#  [ 0.43304912]
#  [ 0.50036858]]
# El error es: [[-0.4735653 ]
#  [-0.43304912]
#  [ 0.49963142]]
# end train.
# inputs  [ 0.  0.  1.]
# targets  [ 0.  1.  0.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47198619]
#  [ 0.50019427]
#  [ 0.51229752]]
# El error es: [[-0.47198619]
#  [ 0.49980573]
#  [-0.51229752]]
# end train.
# inputs  [ 0.  1.  0.]
# targets  [ 0.  1.  1.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45633194]
#  [ 0.43353749]
#  [ 0.48579847]]
# El error es: [[-0.45633194]
#  [ 0.56646251]
#  [ 0.51420153]]
# end train.
# inputs  [ 0.  1.  1.]
# targets  [ 1.  0.  0.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45762827]
#  [ 0.49664488]
#  [ 0.49809169]]
# El error es: [[ 0.54237173]
#  [-0.49664488]
#  [-0.49809169]]
# end train.
# inputs  [ 1.  0.  0.]
# targets  [ 1.  0.  1.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48114117]
#  [ 0.44729166]
#  [ 0.51333061]]
# El error es: [[ 0.51885883]
#  [-0.44729166]
#  [ 0.48666939]]
# end train.
# inputs  [ 1.  0.  1.]
# targets  [ 1.  1.  0.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48240974]
#  [ 0.51185868]
#  [ 0.52275143]]
# El error es: [[ 0.51759026]
#  [ 0.48814132]
#  [-0.52275143]]
# end train.
# inputs  [ 1.  1.  0.]
# targets  [ 1.  1.  1.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47134752]
#  [ 0.44786337]
#  [ 0.49880049]]
# El error es: [[ 0.52865248]
#  [ 0.55213663]
#  [ 0.50119951]]
# end train.
# inputs  [ 1.  1.  1.]
# targets  [ 0.  0.  0.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47530765]
#  [ 0.50947369]
#  [ 0.5103006 ]]
# El error es: [[-0.47530765]
#  [-0.50947369]
#  [-0.5103006 ]]
# end train.
# inputs  [ 0.  0.  0.]
# targets  [ 0.  0.  1.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47408884]
#  [ 0.43389902]
#  [ 0.50277925]]
# El error es: [[-0.47408884]
#  [-0.43389902]
#  [ 0.49722075]]
# end train.
# inputs  [ 0.  0.  1.]
# targets  [ 0.  1.  0.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47210149]
#  [ 0.50026518]
#  [ 0.51271663]]
# El error es: [[-0.47210149]
#  [ 0.49973482]
#  [-0.51271663]]
# end train.
# inputs  [ 0.  1.  0.]
# targets  [ 0.  1.  1.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45673788]
#  [ 0.43488941]
#  [ 0.48809394]]
# El error es: [[-0.45673788]
#  [ 0.56511059]
#  [ 0.51190606]]
# end train.
# inputs  [ 0.  1.  1.]
# targets  [ 1.  0.  0.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45768863]
#  [ 0.49695597]
#  [ 0.49856741]]
# El error es: [[ 0.54231137]
#  [-0.49695597]
#  [-0.49856741]]
# end train.
# inputs  [ 1.  0.  0.]
# targets  [ 1.  0.  1.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48195034]
#  [ 0.44813521]
#  [ 0.51566225]]
# El error es: [[ 0.51804966]
#  [-0.44813521]
#  [ 0.48433775]]
# end train.
# inputs  [ 1.  0.  1.]
# targets  [ 1.  1.  0.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48280636]
#  [ 0.51199084]
#  [ 0.52316576]]
# El error es: [[ 0.51719364]
#  [ 0.48800916]
#  [-0.52316576]]
# end train.
# inputs  [ 1.  1.  0.]
# targets  [ 1.  1.  1.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47204251]
#  [ 0.44921333]
#  [ 0.50102861]]
# El error es: [[ 0.52795749]
#  [ 0.55078667]
#  [ 0.49897139]]
# end train.
# inputs  [ 1.  1.  1.]
# targets  [ 0.  0.  0.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47562031]
#  [ 0.50981935]
#  [ 0.51073642]]
# El error es: [[-0.47562031]
#  [-0.50981935]
#  [-0.51073642]]
# end train.
# inputs  [ 0.  0.  0.]
# targets  [ 0.  0.  1.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47459082]
#  [ 0.4347225 ]
#  [ 0.50514732]]
# El error es: [[-0.47459082]
#  [-0.4347225 ]
#  [ 0.49485268]]
# end train.
# inputs  [ 0.  0.  1.]
# targets  [ 0.  1.  0.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47219517]
#  [ 0.50033426]
#  [ 0.51312781]]
# El error es: [[-0.47219517]
#  [ 0.49966574]
#  [-0.51312781]]
# end train.
# inputs  [ 0.  1.  0.]
# targets  [ 0.  1.  1.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45712046]
#  [ 0.43620111]
#  [ 0.49031882]]
# El error es: [[-0.45712046]
#  [ 0.56379889]
#  [ 0.50968118]]
# end train.
# inputs  [ 0.  1.  1.]
# targets  [ 1.  0.  0.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45772714]
#  [ 0.49725424]
#  [ 0.4990187 ]]
# El error es: [[ 0.54227286]
#  [-0.49725424]
#  [-0.4990187 ]]
# end train.
# inputs  [ 1.  0.  0.]
# targets  [ 1.  0.  1.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48274126]
#  [ 0.44894028]
#  [ 0.51795691]]
# El error es: [[ 0.51725874]
#  [-0.44894028]
#  [ 0.48204309]]
# end train.
# inputs  [ 1.  0.  1.]
# targets  [ 1.  1.  0.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48318447]
#  [ 0.51211308]
#  [ 0.52357458]]
# El error es: [[ 0.51681553]
#  [ 0.48788692]
#  [-0.52357458]]
# end train.
# inputs  [ 1.  1.  0.]
# targets  [ 1.  1.  1.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47271778]
#  [ 0.45051198]
#  [ 0.50319228]]
# El error es: [[ 0.52728222]
#  [ 0.54948802]
#  [ 0.49680772]]
# end train.
# inputs  [ 1.  1.  1.]
# targets  [ 0.  0.  0.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47591413]
#  [ 0.51014714]
#  [ 0.51115159]]
# El error es: [[-0.47591413]
#  [-0.51014714]
#  [-0.51115159]]
# end train.
# inputs  [ 0.  0.  0.]
# targets  [ 0.  0.  1.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47507222]
#  [ 0.43552037]
#  [ 0.50747428]]
# El error es: [[-0.47507222]
#  [-0.43552037]
#  [ 0.49252572]]
# end train.
# inputs  [ 0.  0.  1.]
# targets  [ 0.  1.  0.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47226779]
#  [ 0.50040166]
#  [ 0.51353018]]
# El error es: [[-0.47226779]
#  [ 0.49959834]
#  [-0.51353018]]
# end train.
# inputs  [ 0.  1.  0.]
# targets  [ 0.  1.  1.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45748076]
#  [ 0.43747411]
#  [ 0.49247588]]
# El error es: [[-0.45748076]
#  [ 0.56252589]
#  [ 0.50752412]]
# end train.
# inputs  [ 0.  1.  1.]
# targets  [ 1.  0.  0.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45774439]
#  [ 0.49754031]
#  [ 0.49944566]]
# El error es: [[ 0.54225561]
#  [-0.49754031]
#  [-0.49944566]]
# end train.
# inputs  [ 1.  0.  0.]
# targets  [ 1.  0.  1.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48351517]
#  [ 0.44970824]
#  [ 0.52021729]]
# El error es: [[ 0.51648483]
#  [-0.44970824]
#  [ 0.47978271]]
# end train.
# inputs  [ 1.  0.  1.]
# targets  [ 1.  1.  0.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48354478]
#  [ 0.51222604]
#  [ 0.52397793]]
# El error es: [[ 0.51645522]
#  [ 0.48777396]
#  [-0.52397793]]
# end train.
# inputs  [ 1.  1.  0.]
# targets  [ 1.  1.  1.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47337463]
#  [ 0.45176145]
#  [ 0.50529536]]
# El error es: [[ 0.52662537]
#  [ 0.54823855]
#  [ 0.49470464]]
# end train.
# inputs  [ 1.  1.  1.]
# targets  [ 0.  0.  0.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47618991]
#  [ 0.51045813]
#  [ 0.51154693]]
# El error es: [[-0.47618991]
#  [-0.51045813]
#  [-0.51154693]]
# end train.
# inputs  [ 0.  0.  0.]
# targets  [ 0.  0.  1.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47553399]
#  [ 0.4362934 ]
#  [ 0.50976159]]
# El error es: [[-0.47553399]
#  [-0.4362934 ]
#  [ 0.49023841]]
# end train.
# inputs  [ 0.  0.  1.]
# targets  [ 0.  1.  0.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47231982]
#  [ 0.50046751]
#  [ 0.51392287]]
# El error es: [[-0.47231982]
#  [ 0.49953249]
#  [-0.51392287]]
# end train.
# inputs  [ 0.  1.  0.]
# targets  [ 0.  1.  1.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45781981]
#  [ 0.43870991]
#  [ 0.49456776]]
# El error es: [[-0.45781981]
#  [ 0.56129009]
#  [ 0.50543224]]
# end train.
# inputs  [ 0.  1.  1.]
# targets  [ 1.  0.  0.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45774097]
#  [ 0.49781475]
#  [ 0.49984839]]
# El error es: [[ 0.54225903]
#  [-0.49781475]
#  [-0.49984839]]
# end train.
# inputs  [ 1.  0.  0.]
# targets  [ 1.  0.  1.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48427326]
#  [ 0.45044043]
#  [ 0.52244596]]
# El error es: [[ 0.51572674]
#  [-0.45044043]
#  [ 0.47755404]]
# end train.
# inputs  [ 1.  0.  1.]
# targets  [ 1.  1.  0.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48388798]
#  [ 0.51233029]
#  [ 0.52437578]]
# El error es: [[ 0.51611202]
#  [ 0.48766971]
#  [-0.52437578]]
# end train.
# inputs  [ 1.  1.  0.]
# targets  [ 1.  1.  1.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47401433]
#  [ 0.45296373]
#  [ 0.50734158]]
# El error es: [[ 0.52598567]
#  [ 0.54703627]
#  [ 0.49265842]]
# end train.
# inputs  [ 1.  1.  1.]
# targets  [ 0.  0.  0.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47644841]
#  [ 0.51075329]
#  [ 0.51192322]]
# El error es: [[-0.47644841]
#  [-0.51075329]
#  [-0.51192322]]
# end train.
# inputs  [ 0.  0.  0.]
# targets  [ 0.  0.  1.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47597705]
#  [ 0.43704236]
#  [ 0.51201066]]
# El error es: [[-0.47597705]
#  [-0.43704236]
#  [ 0.48798934]]
# end train.
# inputs  [ 0.  0.  1.]
# targets  [ 0.  1.  0.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47235176]
#  [ 0.50053194]
#  [ 0.51430505]]
# El error es: [[-0.47235176]
#  [ 0.49946806]
#  [-0.51430505]]
# end train.
# inputs  [ 0.  1.  0.]
# targets  [ 0.  1.  1.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45813861]
#  [ 0.4399099 ]
#  [ 0.496597  ]]
# El error es: [[-0.45813861]
#  [ 0.5600901 ]
#  [ 0.503403  ]]
# end train.
# inputs  [ 0.  1.  1.]
# targets  [ 1.  0.  0.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45771742]
#  [ 0.49807808]
#  [ 0.50022696]]
# El error es: [[ 0.54228258]
#  [-0.49807808]
#  [-0.50022696]]
# end train.
# inputs  [ 1.  0.  0.]
# targets  [ 1.  0.  1.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48501666]
#  [ 0.45113807]
#  [ 0.52464539]]
# El error es: [[ 0.51498334]
#  [-0.45113807]
#  [ 0.47535461]]
# end train.
# inputs  [ 1.  0.  1.]
# targets  [ 1.  1.  0.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48421473]
#  [ 0.51242637]
#  [ 0.52476811]]
# El error es: [[ 0.51578527]
#  [ 0.48757363]
#  [-0.52476811]]
# end train.
# inputs  [ 1.  1.  0.]
# targets  [ 1.  1.  1.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47463807]
#  [ 0.45412072]
#  [ 0.50933444]]
# El error es: [[ 0.52536193]
#  [ 0.54587928]
#  [ 0.49066556]]
# end train.
# inputs  [ 1.  1.  1.]
# targets  [ 0.  0.  0.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47669038]
#  [ 0.51103355]
#  [ 0.51228117]]
# El error es: [[-0.47669038]
#  [-0.51103355]
#  [-0.51228117]]
# end train.
# inputs  [ 0.  0.  0.]
# targets  [ 0.  0.  1.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47640228]
#  [ 0.43776797]
#  [ 0.51422284]]
# El error es: [[-0.47640228]
#  [-0.43776797]
#  [ 0.48577716]]
# end train.
# inputs  [ 0.  0.  1.]
# targets  [ 0.  1.  0.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47236406]
#  [ 0.50059502]
#  [ 0.51467594]]
# El error es: [[-0.47236406]
#  [ 0.49940498]
#  [-0.51467594]]
# end train.
# inputs  [ 0.  1.  0.]
# targets  [ 0.  1.  1.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45843809]
#  [ 0.44107544]
#  [ 0.49856602]]
# El error es: [[-0.45843809]
#  [ 0.55892456]
#  [ 0.50143398]]
# end train.
# inputs  [ 0.  1.  1.]
# targets  [ 1.  0.  0.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45767425]
#  [ 0.4983308 ]
#  [ 0.50058143]]
# El error es: [[ 0.54232575]
#  [-0.4983308 ]
#  [-0.50058143]]
# end train.
# inputs  [ 1.  0.  0.]
# targets  [ 1.  0.  1.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48574647]
#  [ 0.45180234]
#  [ 0.52681794]]
# El error es: [[ 0.51425353]
#  [-0.45180234]
#  [ 0.47318206]]
# end train.
# inputs  [ 1.  0.  1.]
# targets  [ 1.  1.  0.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48452565]
#  [ 0.51251476]
#  [ 0.5251549 ]]
# El error es: [[ 0.51547435]
#  [ 0.48748524]
#  [-0.5251549 ]]
# end train.
# inputs  [ 1.  1.  0.]
# targets  [ 1.  1.  1.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47524702]
#  [ 0.4552342 ]
#  [ 0.51127732]]
# El error es: [[ 0.52475298]
#  [ 0.5447658 ]
#  [ 0.48872268]]
# end train.
# inputs  [ 1.  1.  1.]
# targets  [ 0.  0.  0.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.4769165 ]
#  [ 0.51129977]
#  [ 0.51262143]]
# El error es: [[-0.4769165 ]
#  [-0.51129977]
#  [-0.51262143]]
# end train.
# inputs  [ 0.  0.  0.]
# targets  [ 0.  0.  1.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.4768105 ]
#  [ 0.43847091]
#  [ 0.51639943]]
# El error es: [[-0.4768105 ]
#  [-0.43847091]
#  [ 0.48360057]]
# end train.
# inputs  [ 0.  0.  1.]
# targets  [ 0.  1.  0.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47235714]
#  [ 0.50065682]
#  [ 0.51503475]]
# El error es: [[-0.47235714]
#  [ 0.49934318]
#  [-0.51503475]]
# end train.
# inputs  [ 0.  1.  0.]
# targets  [ 0.  1.  1.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45871916]
#  [ 0.44220779]
#  [ 0.50047714]]
# El error es: [[-0.45871916]
#  [ 0.55779221]
#  [ 0.49952286]]
# end train.
# inputs  [ 0.  1.  1.]
# targets  [ 1.  0.  0.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45761195]
#  [ 0.49857336]
#  [ 0.50091187]]
# El error es: [[ 0.54238805]
#  [-0.49857336]
#  [-0.50091187]]
# end train.
# inputs  [ 1.  0.  0.]
# targets  [ 1.  0.  1.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48646373]
#  [ 0.45243435]
#  [ 0.52896585]]
# El error es: [[ 0.51353627]
#  [-0.45243435]
#  [ 0.47103415]]
# end train.
# inputs  [ 1.  0.  1.]
# targets  [ 1.  1.  0.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48482134]
#  [ 0.51259592]
#  [ 0.52553608]]
# El error es: [[ 0.51517866]
#  [ 0.48740408]
#  [-0.52553608]]
# end train.
# inputs  [ 1.  1.  0.]
# targets  [ 1.  1.  1.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47584225]
#  [ 0.45630587]
#  [ 0.5131734 ]]
# El error es: [[ 0.52415775]
#  [ 0.54369413]
#  [ 0.4868266 ]]
# end train.
# inputs  [ 1.  1.  1.]
# targets  [ 0.  0.  0.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47712742]
#  [ 0.51155275]
#  [ 0.51294462]]
# El error es: [[-0.47712742]
#  [-0.51155275]
#  [-0.51294462]]
# end train.
# inputs  [ 0.  0.  0.]
# targets  [ 0.  0.  1.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47720254]
#  [ 0.43915186]
#  [ 0.51854169]]
# El error es: [[-0.47720254]
#  [-0.43915186]
#  [ 0.48145831]]
# end train.
# inputs  [ 0.  0.  1.]
# targets  [ 0.  1.  0.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47233141]
#  [ 0.5007174 ]
#  [ 0.51538073]]
# El error es: [[-0.47233141]
#  [ 0.4992826 ]
#  [-0.51538073]]
# end train.
# inputs  [ 0.  1.  0.]
# targets  [ 0.  1.  1.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45898267]
#  [ 0.44330818]
#  [ 0.50233258]]
# El error es: [[-0.45898267]
#  [ 0.55669182]
#  [ 0.49766742]]
# end train.
# inputs  [ 0.  1.  1.]
# targets  [ 1.  0.  0.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45753097]
#  [ 0.4988062 ]
#  [ 0.50121831]]
# El error es: [[ 0.54246903]
#  [-0.4988062 ]
#  [-0.50121831]]
# end train.
# inputs  [ 1.  0.  0.]
# targets  [ 1.  0.  1.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48716945]
#  [ 0.45303515]
#  [ 0.53109128]]
# El error es: [[ 0.51283055]
#  [-0.45303515]
#  [ 0.46890872]]
# end train.
# inputs  [ 1.  0.  1.]
# targets  [ 1.  1.  0.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48510235]
#  [ 0.51267028]
#  [ 0.52591161]]
# El error es: [[ 0.51489765]
#  [ 0.48732972]
#  [-0.52591161]]
# end train.
# inputs  [ 1.  1.  0.]
# targets  [ 1.  1.  1.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47642483]
#  [ 0.45733733]
#  [ 0.51502576]]
# El error es: [[ 0.52357517]
#  [ 0.54266267]
#  [ 0.48497424]]
# end train.
# inputs  [ 1.  1.  1.]
# targets  [ 0.  0.  0.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47732377]
#  [ 0.51179324]
#  [ 0.51325129]]
# El error es: [[-0.47732377]
#  [-0.51179324]
#  [-0.51325129]]
# end train.
# inputs  [ 0.  0.  0.]
# targets  [ 0.  0.  1.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47757916]
#  [ 0.43981146]
#  [ 0.52065084]]
# El error es: [[-0.47757916]
#  [-0.43981146]
#  [ 0.47934916]]
# end train.
# inputs  [ 0.  0.  1.]
# targets  [ 0.  1.  0.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47228725]
#  [ 0.5007768 ]
#  [ 0.51571317]]
# El error es: [[-0.47228725]
#  [ 0.4992232 ]
#  [-0.51571317]]
# end train.
# inputs  [ 0.  1.  0.]
# targets  [ 0.  1.  1.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45922943]
#  [ 0.44437777]
#  [ 0.50413444]]
# El error es: [[-0.45922943]
#  [ 0.55562223]
#  [ 0.49586556]]
# end train.
# inputs  [ 0.  1.  1.]
# targets  [ 1.  0.  0.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45743175]
#  [ 0.49902969]
#  [ 0.50150078]]
# El error es: [[ 0.54256825]
#  [-0.49902969]
#  [-0.50150078]]
# end train.
# inputs  [ 1.  0.  0.]
# targets  [ 1.  0.  1.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48786459]
#  [ 0.45360572]
#  [ 0.53319629]]
# El error es: [[ 0.51213541]
#  [-0.45360572]
#  [ 0.46680371]]
# end train.
# inputs  [ 1.  0.  1.]
# targets  [ 1.  1.  0.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48536923]
#  [ 0.51273821]
#  [ 0.5262814 ]]
# El error es: [[ 0.51463077]
#  [ 0.48726179]
#  [-0.5262814 ]]
# end train.
# inputs  [ 1.  1.  0.]
# targets  [ 1.  1.  1.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47699576]
#  [ 0.45833007]
#  [ 0.51683729]]
# El error es: [[ 0.52300424]
#  [ 0.54166993]
#  [ 0.48316271]]
# end train.
# inputs  [ 1.  1.  1.]
# targets  [ 0.  0.  0.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47750613]
#  [ 0.51202193]
#  [ 0.51354196]]
# El error es: [[-0.47750613]
#  [-0.51202193]
#  [-0.51354196]]
# end train.
# inputs  [ 0.  0.  0.]
# targets  [ 0.  0.  1.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47794111]
#  [ 0.44045033]
#  [ 0.52272803]]
# El error es: [[-0.47794111]
#  [-0.44045033]
#  [ 0.47727197]]
# end train.
# inputs  [ 0.  0.  1.]
# targets  [ 0.  1.  0.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47222502]
#  [ 0.50083502]
#  [ 0.51603136]]
# El error es: [[-0.47222502]
#  [ 0.49916498]
#  [-0.51603136]]
# end train.
# inputs  [ 0.  1.  0.]
# targets  [ 0.  1.  1.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45946025]
#  [ 0.44541768]
#  [ 0.50588477]]
# El error es: [[-0.45946025]
#  [ 0.55458232]
#  [ 0.49411523]]
# end train.
# inputs  [ 0.  1.  1.]
# targets  [ 1.  0.  0.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45731468]
#  [ 0.49924422]
#  [ 0.50175932]]
# El error es: [[ 0.54268532]
#  [-0.49924422]
#  [-0.50175932]]
# end train.
# inputs  [ 1.  0.  0.]
# targets  [ 1.  0.  1.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48855008]
#  [ 0.45414701]
#  [ 0.53528285]]
# El error es: [[ 0.51144992]
#  [-0.45414701]
#  [ 0.46471715]]
# end train.
# inputs  [ 1.  0.  1.]
# targets  [ 1.  1.  0.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.4856225 ]
#  [ 0.51280006]
#  [ 0.52664539]]
# El error es: [[ 0.5143775 ]
#  [ 0.48719994]
#  [-0.52664539]]
# end train.
# inputs  [ 1.  1.  0.]
# targets  [ 1.  1.  1.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.477556  ]
#  [ 0.45928552]
#  [ 0.51861079]]
# El error es: [[ 0.522444  ]
#  [ 0.54071448]
#  [ 0.48138921]]
# end train.
# inputs  [ 1.  1.  1.]
# targets  [ 0.  0.  0.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47767506]
#  [ 0.51223948]
#  [ 0.51381713]]
# El error es: [[-0.47767506]
#  [-0.51223948]
#  [-0.51381713]]
# end train.
# inputs  [ 0.  0.  0.]
# targets  [ 0.  0.  1.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47828911]
#  [ 0.44106907]
#  [ 0.52477438]]
# El error es: [[-0.47828911]
#  [-0.44106907]
#  [ 0.47522562]]
# end train.
# inputs  [ 0.  0.  1.]
# targets  [ 0.  1.  0.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47214506]
#  [ 0.50089208]
#  [ 0.51633463]]
# El error es: [[-0.47214506]
#  [ 0.49910792]
#  [-0.51633463]]
# end train.
# inputs  [ 0.  1.  0.]
# targets  [ 0.  1.  1.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45967584]
#  [ 0.44642897]
#  [ 0.50758547]]
# El error es: [[-0.45967584]
#  [ 0.55357103]
#  [ 0.49241453]]
# end train.
# inputs  [ 0.  1.  1.]
# targets  [ 1.  0.  0.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45718015]
#  [ 0.49945011]
#  [ 0.50199395]]
# El error es: [[ 0.54281985]
#  [-0.49945011]
#  [-0.50199395]]
# end train.
# inputs  [ 1.  0.  0.]
# targets  [ 1.  0.  1.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48922683]
#  [ 0.4546599 ]
#  [ 0.53735284]]
# El error es: [[ 0.51077317]
#  [-0.4546599 ]
#  [ 0.46264716]]
# end train.
# inputs  [ 1.  0.  1.]
# targets  [ 1.  1.  0.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48586264]
#  [ 0.51285617]
#  [ 0.52700349]]
# El error es: [[ 0.51413736]
#  [ 0.48714383]
#  [-0.52700349]]
# end train.
# inputs  [ 1.  1.  0.]
# targets  [ 1.  1.  1.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47810647]
#  [ 0.46020503]
#  [ 0.52034893]]
# El error es: [[ 0.52189353]
#  [ 0.53979497]
#  [ 0.47965107]]
# end train.
# inputs  [ 1.  1.  1.]
# targets  [ 0.  0.  0.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47783108]
#  [ 0.51244648]
#  [ 0.51407724]]
# El error es: [[-0.47783108]
#  [-0.51244648]
#  [-0.51407724]]
# end train.
# inputs  [ 0.  0.  0.]
# targets  [ 0.  0.  1.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47862385]
#  [ 0.44166825]
#  [ 0.52679095]]
# El error es: [[-0.47862385]
#  [-0.44166825]
#  [ 0.47320905]]
# end train.
# inputs  [ 0.  0.  1.]
# targets  [ 0.  1.  0.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47204768]
#  [ 0.50094797]
#  [ 0.51662232]]
# El error es: [[-0.47204768]
#  [ 0.49905203]
#  [-0.51662232]]
# end train.
# inputs  [ 0.  1.  0.]
# targets  [ 0.  1.  1.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45987695]
#  [ 0.44741265]
#  [ 0.50923842]]
# El error es: [[-0.45987695]
#  [ 0.55258735]
#  [ 0.49076158]]
# end train.
# inputs  [ 0.  1.  1.]
# targets  [ 1.  0.  0.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45702849]
#  [ 0.49964768]
#  [ 0.50220466]]
# El error es: [[ 0.54297151]
#  [-0.49964768]
#  [-0.50220466]]
# end train.
# inputs  [ 1.  0.  0.]
# targets  [ 1.  0.  1.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48989568]
#  [ 0.45514525]
#  [ 0.53940807]]
# El error es: [[ 0.51010432]
#  [-0.45514525]
#  [ 0.46059193]]
# end train.
# inputs  [ 1.  0.  1.]
# targets  [ 1.  1.  0.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.4860901 ]
#  [ 0.51290681]
#  [ 0.5273556 ]]
# El error es: [[ 0.5139099 ]
#  [ 0.48709319]
#  [-0.5273556 ]]
# end train.
# inputs  [ 1.  1.  0.]
# targets  [ 1.  1.  1.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47864807]
#  [ 0.46108986]
#  [ 0.52205424]]
# El error es: [[ 0.52135193]
#  [ 0.53891014]
#  [ 0.47794576]]
# end train.
# inputs  [ 1.  1.  1.]
# targets  [ 0.  0.  0.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47797468]
#  [ 0.51264349]
#  [ 0.51432271]]
# El error es: [[-0.47797468]
#  [-0.51264349]
#  [-0.51432271]]
# end train.
# inputs  [ 0.  0.  0.]
# targets  [ 0.  0.  1.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.478946  ]
#  [ 0.44224843]
#  [ 0.52877876]]
# El error es: [[-0.478946  ]
#  [-0.44224843]
#  [ 0.47122124]]
# end train.
# inputs  [ 0.  0.  1.]
# targets  [ 0.  1.  0.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47193318]
#  [ 0.50100267]
#  [ 0.51689379]]
# El error es: [[-0.47193318]
#  [ 0.49899733]
#  [-0.51689379]]
# end train.
# inputs  [ 0.  1.  0.]
# targets  [ 0.  1.  1.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.46006424]
#  [ 0.44836969]
#  [ 0.51084536]]
# El error es: [[-0.46006424]
#  [ 0.55163031]
#  [ 0.48915464]]
# end train.
# inputs  [ 0.  1.  1.]
# targets  [ 1.  0.  0.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45686004]
#  [ 0.49983721]
#  [ 0.50239146]]
# El error es: [[ 0.54313996]
#  [-0.49983721]
#  [-0.50239146]]
# end train.
# inputs  [ 1.  0.  0.]
# targets  [ 1.  0.  1.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.49055747]
#  [ 0.45560384]
#  [ 0.54145026]]
# El error es: [[ 0.50944253]
#  [-0.45560384]
#  [ 0.45854974]]
# end train.
# inputs  [ 1.  0.  1.]
# targets  [ 1.  1.  0.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48630534]
#  [ 0.51295226]
#  [ 0.52770163]]
# El error es: [[ 0.51369466]
#  [ 0.48704774]
#  [-0.52770163]]
# end train.
# inputs  [ 1.  1.  0.]
# targets  [ 1.  1.  1.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47918164]
#  [ 0.46194122]
#  [ 0.52372917]]
# El error es: [[ 0.52081836]
#  [ 0.53805878]
#  [ 0.47627083]]
# end train.
# inputs  [ 1.  1.  1.]
# targets  [ 0.  0.  0.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47810633]
#  [ 0.51283104]
#  [ 0.51455391]]
# El error es: [[-0.47810633]
#  [-0.51283104]
#  [-0.51455391]]
# end train.
# inputs  [ 0.  0.  0.]
# targets  [ 0.  0.  1.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.4792562 ]
#  [ 0.44281014]
#  [ 0.5307388 ]]
# El error es: [[-0.4792562 ]
#  [-0.44281014]
#  [ 0.4692612 ]]
# end train.
# inputs  [ 0.  0.  1.]
# targets  [ 0.  1.  0.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47180183]
#  [ 0.50105614]
#  [ 0.51714844]]
# El error es: [[-0.47180183]
#  [ 0.49894386]
#  [-0.51714844]]
# end train.
# inputs  [ 0.  1.  0.]
# targets  [ 0.  1.  1.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.46023838]
#  [ 0.44930103]
#  [ 0.512408  ]]
# El error es: [[-0.46023838]
#  [ 0.55069897]
#  [ 0.487592  ]]
# end train.
# inputs  [ 0.  1.  1.]
# targets  [ 1.  0.  0.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45667511]
#  [ 0.50001898]
#  [ 0.50255434]]
# El error es: [[ 0.54332489]
#  [-0.50001898]
#  [-0.50255434]]
# end train.
# inputs  [ 1.  0.  0.]
# targets  [ 1.  0.  1.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.491213  ]
#  [ 0.45603644]
#  [ 0.54348108]]
# El error es: [[ 0.508787  ]
#  [-0.45603644]
#  [ 0.45651892]]
# end train.
# inputs  [ 1.  0.  1.]
# targets  [ 1.  1.  0.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48650876]
#  [ 0.51299275]
#  [ 0.52804148]]
# El error es: [[ 0.51349124]
#  [ 0.48700725]
#  [-0.52804148]]
# end train.
# inputs  [ 1.  1.  0.]
# targets  [ 1.  1.  1.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47970802]
#  [ 0.46276024]
#  [ 0.52537607]]
# El error es: [[ 0.52029198]
#  [ 0.53723976]
#  [ 0.47462393]]
# end train.
# inputs  [ 1.  1.  1.]
# targets  [ 0.  0.  0.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47822647]
#  [ 0.5130096 ]
#  [ 0.51477123]]
# El error es: [[-0.47822647]
#  [-0.5130096 ]
#  [-0.51477123]]
# end train.
# inputs  [ 0.  0.  0.]
# targets  [ 0.  0.  1.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47955506]
#  [ 0.44335392]
#  [ 0.53267199]]
# El error es: [[-0.47955506]
#  [-0.44335392]
#  [ 0.46732801]]
# end train.
# inputs  [ 0.  0.  1.]
# targets  [ 0.  1.  0.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47165388]
#  [ 0.50110835]
#  [ 0.51738567]]
# El error es: [[-0.47165388]
#  [ 0.49889165]
#  [-0.51738567]]
# end train.
# inputs  [ 0.  1.  0.]
# targets  [ 0.  1.  1.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.46039999]
#  [ 0.45020754]
#  [ 0.51392793]]
# El error es: [[-0.46039999]
#  [ 0.54979246]
#  [ 0.48607207]]
# end train.
# inputs  [ 0.  1.  1.]
# targets  [ 1.  0.  0.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45647396]
#  [ 0.50019324]
#  [ 0.5026933 ]]
# El error es: [[ 0.54352604]
#  [-0.50019324]
#  [-0.5026933 ]]
# end train.
# inputs  [ 1.  0.  0.]
# targets  [ 1.  0.  1.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.49186305]
#  [ 0.45644377]
#  [ 0.54550211]]
# El error es: [[ 0.50813695]
#  [-0.45644377]
#  [ 0.45449789]]
# end train.
# inputs  [ 1.  0.  1.]
# targets  [ 1.  1.  0.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48670075]
#  [ 0.51302852]
#  [ 0.52837503]]
# El error es: [[ 0.51329925]
#  [ 0.48697148]
#  [-0.52837503]]
# end train.
# inputs  [ 1.  1.  0.]
# targets  [ 1.  1.  1.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48022799]
#  [ 0.46354799]
#  [ 0.52699717]]
# El error es: [[ 0.51977201]
#  [ 0.53645201]
#  [ 0.47300283]]
# end train.
# inputs  [ 1.  1.  1.]
# targets  [ 0.  0.  0.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.4783355 ]
#  [ 0.51317963]
#  [ 0.51497497]]
# El error es: [[-0.4783355 ]
#  [-0.51317963]
#  [-0.51497497]]
# end train.
# inputs  [ 0.  0.  0.]
# targets  [ 0.  0.  1.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47984318]
#  [ 0.44388027]
#  [ 0.53457923]]
# El error es: [[-0.47984318]
#  [-0.44388027]
#  [ 0.46542077]]
# end train.
# inputs  [ 0.  0.  1.]
# targets  [ 0.  1.  0.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.47148958]
#  [ 0.50115925]
#  [ 0.51760489]]
# El error es: [[-0.47148958]
#  [ 0.49884075]
#  [-0.51760489]]
# end train.
# inputs  [ 0.  1.  0.]
# targets  [ 0.  1.  1.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.46054968]
#  [ 0.45109008]
#  [ 0.5154067 ]]
# El error es: [[-0.46054968]
#  [ 0.54890992]
#  [ 0.4845933 ]]
# end train.
# inputs  [ 0.  1.  1.]
# targets  [ 1.  0.  0.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.45625687]
#  [ 0.50036022]
#  [ 0.50280831]]
# El error es: [[ 0.54374313]
#  [-0.50036022]
#  [-0.50280831]]
# end train.
# inputs  [ 1.  0.  0.]
# targets  [ 1.  0.  1.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# targets
# ...
#  [-0.27457748]]
# end train.
# inputs  [ 1.  0.  0.]
# targets  [ 1.  0.  1.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.62174384]
#  [ 0.44372414]
#  [ 0.84112684]]
# El error es: [[ 0.37825616]
#  [-0.44372414]
#  [ 0.15887316]]
# end train.
# inputs  [ 1.  0.  1.]
# targets  [ 1.  1.  0.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.41123451]
#  [ 0.49780083]
#  [ 0.38881943]]
# El error es: [[ 0.58876549]
#  [ 0.50219917]
#  [-0.38881943]]
# end train.
# inputs  [ 1.  1.  0.]
# targets  [ 1.  1.  1.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.60231011]
#  [ 0.47169097]
#  [ 0.80673535]]
# El error es: [[ 0.39768989]
#  [ 0.52830903]
#  [ 0.19326465]]
# end train.
# inputs  [ 1.  1.  1.]
# targets  [ 0.  0.  0.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.39676305]
#  [ 0.51476582]
#  [ 0.35563712]]
# El error es: [[-0.39676305]
#  [-0.51476582]
#  [-0.35563712]]
# end train.
# inputs  [ 0.  0.  0.]
# targets  [ 0.  0.  1.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.52050219]
#  [ 0.47391325]
#  [ 0.66286631]]
# El error es: [[-0.52050219]
#  [-0.47391325]
#  [ 0.33713369]]
# end train.
# inputs  [ 0.  0.  1.]
# targets  [ 0.  1.  0.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.35240473]
#  [ 0.49505948]
#  [ 0.28082829]]
# El error es: [[-0.35240473]
#  [ 0.50494052]
#  [-0.28082829]]
# end train.
# inputs  [ 0.  1.  0.]
# targets  [ 0.  1.  1.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48318998]
#  [ 0.50935289]
#  [ 0.58769104]]
# El error es: [[-0.48318998]
#  [ 0.49064711]
#  [ 0.41230896]]
# end train.
# inputs  [ 0.  1.  1.]
# targets  [ 1.  0.  0.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.3433938 ]
#  [ 0.50629563]
#  [ 0.27233742]]
# El error es: [[ 0.6566062 ]
#  [-0.50629563]
#  [-0.27233742]]
# end train.
# inputs  [ 1.  0.  0.]
# targets  [ 1.  0.  1.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.62270949]
#  [ 0.44381165]
#  [ 0.84294319]]
# El error es: [[ 0.37729051]
#  [-0.44381165]
#  [ 0.15705681]]
# end train.
# inputs  [ 1.  0.  1.]
# targets  [ 1.  1.  0.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.41025594]
#  [ 0.49771132]
#  [ 0.3860649 ]]
# El error es: [[ 0.58974406]
#  [ 0.50228868]
#  [-0.3860649 ]]
# end train.
# inputs  [ 1.  1.  0.]
# targets  [ 1.  1.  1.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.60352027]
#  [ 0.47190685]
#  [ 0.80920038]]
# El error es: [[ 0.39647973]
#  [ 0.52809315]
#  [ 0.19079962]]
# end train.
# inputs  [ 1.  1.  1.]
# targets  [ 0.  0.  0.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.39600928]
#  [ 0.51487831]
#  [ 0.35326759]]
# El error es: [[-0.39600928]
#  [-0.51487831]
#  [-0.35326759]]
# end train.
# inputs  [ 0.  0.  0.]
# targets  [ 0.  0.  1.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.52088463]
#  [ 0.47423826]
#  [ 0.6635909 ]]
# El error es: [[-0.52088463]
#  [-0.47423826]
#  [ 0.3364091 ]]
# end train.
# inputs  [ 0.  0.  1.]
# targets  [ 0.  1.  0.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.35175061]
#  [ 0.4951023 ]
#  [ 0.27827897]]
# El error es: [[-0.35175061]
#  [ 0.5048977 ]
#  [-0.27827897]]
# end train.
# inputs  [ 0.  1.  0.]
# targets  [ 0.  1.  1.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48374029]
#  [ 0.50995286]
#  [ 0.5887621 ]]
# El error es: [[-0.48374029]
#  [ 0.49004714]
#  [ 0.4112379 ]]
# end train.
# inputs  [ 0.  1.  1.]
# targets  [ 1.  0.  0.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.34292169]
#  [ 0.50646801]
#  [ 0.27013094]]
# El error es: [[ 0.65707831]
#  [-0.50646801]
#  [-0.27013094]]
# end train.
# inputs  [ 1.  0.  0.]
# targets  [ 1.  0.  1.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.62365928]
#  [ 0.44390107]
#  [ 0.84473893]]
# El error es: [[ 0.37634072]
#  [-0.44390107]
#  [ 0.15526107]]
# end train.
# inputs  [ 1.  0.  1.]
# targets  [ 1.  1.  0.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.40929213]
#  [ 0.49762217]
#  [ 0.38332599]]
# El error es: [[ 0.59070787]
#  [ 0.50237783]
#  [-0.38332599]]
# end train.
# inputs  [ 1.  1.  0.]
# targets  [ 1.  1.  1.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.60471699]
#  [ 0.47212887]
#  [ 0.81164531]]
# El error es: [[ 0.39528301]
#  [ 0.52787113]
#  [ 0.18835469]]
# end train.
# inputs  [ 1.  1.  1.]
# targets  [ 0.  0.  0.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.3952722 ]
#  [ 0.51498992]
#  [ 0.3509251 ]]
# El error es: [[-0.3952722 ]
#  [-0.51498992]
#  [-0.3509251 ]]
# end train.
# inputs  [ 0.  0.  0.]
# targets  [ 0.  0.  1.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.52125966]
#  [ 0.47456305]
#  [ 0.66432069]]
# El error es: [[-0.52125966]
#  [-0.47456305]
#  [ 0.33567931]]
# end train.
# inputs  [ 0.  0.  1.]
# targets  [ 0.  1.  0.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.35111307]
#  [ 0.49514528]
#  [ 0.27576565]]
# El error es: [[-0.35111307]
#  [ 0.50485472]
#  [-0.27576565]]
# end train.
# inputs  [ 0.  1.  0.]
# targets  [ 0.  1.  1.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.4842885 ]
#  [ 0.51055646]
#  [ 0.58985678]]
# El error es: [[-0.4842885 ]
#  [ 0.48944354]
#  [ 0.41014322]]
# end train.
# inputs  [ 0.  1.  1.]
# targets  [ 1.  0.  0.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.34246351]
#  [ 0.50663903]
#  [ 0.26795774]]
# El error es: [[ 0.65753649]
#  [-0.50663903]
#  [-0.26795774]]
# end train.
# inputs  [ 1.  0.  0.]
# targets  [ 1.  0.  1.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.624593  ]
#  [ 0.44399215]
#  [ 0.84651397]]
# El error es: [[ 0.375407  ]
#  [-0.44399215]
#  [ 0.15348603]]
# end train.
# inputs  [ 1.  0.  1.]
# targets  [ 1.  1.  0.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.40834306]
#  [ 0.49753321]
#  [ 0.38060349]]
# El error es: [[ 0.59165694]
#  [ 0.50246679]
#  [-0.38060349]]
# end train.
# inputs  [ 1.  1.  0.]
# targets  [ 1.  1.  1.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.60589972]
#  [ 0.47235682]
#  [ 0.81406946]]
# El error es: [[ 0.39410028]
#  [ 0.52764318]
#  [ 0.18593054]]
# end train.
# inputs  [ 1.  1.  1.]
# targets  [ 0.  0.  0.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.39455137]
#  [ 0.51510039]
#  [ 0.34860968]]
# El error es: [[-0.39455137]
#  [-0.51510039]
#  [-0.34860968]]
# end train.
# inputs  [ 0.  0.  0.]
# targets  [ 0.  0.  1.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.52162715]
#  [ 0.47488749]
#  [ 0.66505554]]
# El error es: [[-0.52162715]
#  [-0.47488749]
#  [ 0.33494446]]
# end train.
# inputs  [ 0.  0.  1.]
# targets  [ 0.  1.  0.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.35049182]
#  [ 0.49518825]
#  [ 0.27328826]]
# El error es: [[-0.35049182]
#  [ 0.50481175]
#  [-0.27328826]]
# end train.
# inputs  [ 0.  1.  0.]
# targets  [ 0.  1.  1.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48483407]
#  [ 0.5111636 ]
#  [ 0.59097447]]
# El error es: [[-0.48483407]
#  [ 0.4888364 ]
#  [ 0.40902553]]
# end train.
# inputs  [ 0.  1.  1.]
# targets  [ 1.  0.  0.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.34201888]
#  [ 0.50680851]
#  [ 0.26581753]]
# El error es: [[ 0.65798112]
#  [-0.50680851]
#  [-0.26581753]]
# end train.
# inputs  [ 1.  0.  0.]
# targets  [ 1.  0.  1.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.6255105 ]
#  [ 0.44408463]
#  [ 0.84826824]]
# El error es: [[ 0.3744895 ]
#  [-0.44408463]
#  [ 0.15173176]]
# end train.
# inputs  [ 1.  0.  1.]
# targets  [ 1.  1.  0.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.40740871]
#  [ 0.49744426]
#  [ 0.3778981 ]]
# El error es: [[ 0.59259129]
#  [ 0.50255574]
#  [-0.3778981 ]]
# end train.
# inputs  [ 1.  1.  0.]
# targets  [ 1.  1.  1.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.60706794]
#  [ 0.47259051]
#  [ 0.81647221]]
# El error es: [[ 0.39293206]
#  [ 0.52740949]
#  [ 0.18352779]]
# end train.
# inputs  [ 1.  1.  1.]
# targets  [ 0.  0.  0.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.39384639]
#  [ 0.51520945]
#  [ 0.34632129]]
# El error es: [[-0.39384639]
#  [-0.51520945]
#  [-0.34632129]]
# end train.
# inputs  [ 0.  0.  0.]
# targets  [ 0.  0.  1.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.52198698]
#  [ 0.47521147]
#  [ 0.6657953 ]]
# El error es: [[-0.52198698]
#  [-0.47521147]
#  [ 0.3342047 ]]
# end train.
# inputs  [ 0.  0.  1.]
# targets  [ 0.  1.  0.]
# inputs
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.34988657]
#  [ 0.49523103]
#  [ 0.27084666]]
# El error es: [[-0.34988657]
#  [ 0.50476897]
#  [-0.27084666]]
# end train.
# inputs  [ 0.  1.  0.]
# targets  [ 0.  1.  1.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.48537653]
#  [ 0.5117742 ]
#  [ 0.59211454]]
# El error es: [[-0.48537653]
#  [ 0.4882258 ]
#  [ 0.40788546]]
# end train.
# inputs  [ 0.  1.  1.]
# targets  [ 1.  0.  0.]
# inputs
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.34158741]
#  [ 0.50697627]
#  [ 0.26370997]]
# El error es: [[ 0.65841259]
#  [-0.50697627]
#  [-0.26370997]]
# end train.
# inputs  [ 1.  0.  0.]
# targets  [ 1.  0.  1.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.62641161]
#  [ 0.44417829]
#  [ 0.85000167]]
# El error es: [[ 0.37358839]
#  [-0.44417829]
#  [ 0.14999833]]
# end train.
# inputs  [ 1.  0.  1.]
# targets  [ 1.  1.  0.]
# inputs
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.40648904]
#  [ 0.49735515]
#  [ 0.37521049]]
# El error es: [[ 0.59351096]
#  [ 0.50264485]
#  [-0.37521049]]
# end train.
# inputs  [ 1.  1.  0.]
# targets  [ 1.  1.  1.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# targets
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.60822118]
#  [ 0.47282974]
#  [ 0.81885298]]
# El error es: [[ 0.39177882]
#  [ 0.52717026]
#  [ 0.18114702]]
# end train.
# inputs  [ 1.  1.  1.]
# targets  [ 0.  0.  0.]
# inputs
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# targets
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# Se realizó multiplicación de matrices y función de activación de hidden
# Se realizó multiplicación de matrices y función de activación de final
# [[ 0.39315684]
#  [ 0.51531688]
#  [ 0.34405982]]
# El error es: [[-0.39315684]
#  [-0.51531688]
#  [-0.34405982]]
# end train.

# %%
# load the mnist test data CSV file into a list
test_data_file = open("mnist_dataset/contador.csv", 'r')
test_data_list = test_data_file.readlines()
test_data_file.close()

# %%
# test the neural network

# scorecard for how well the network performs, initially empty
scorecard = []

# go through all the records in the test data set
for record in test_data_list:
    # split the record by the ',' commas
    all_values = record.split(',')
    # correct answer is first value
    correct_label = int(all_values[0])
    # scale and shift the inputs
    inputs = (numpy.asfarray(all_values[0:3]) / 1.0) + 0.00
    # query the network
    outputs = n.query(inputs)
    print ("Inputs: ", inputs)
    print("Outputs: ", outputs)
    # the index of the highest value corresponds to the label
    label = numpy.argmax(outputs)
    # append correct or incorrect to list
    if (label == correct_label):
        # network's answer matches correct answer, add 1 to scorecard
        scorecard.append(1)
    else:
        # network's answer doesn't match correct answer, add 0 to scorecard
        scorecard.append(0)
        pass
    
    pass
# Out:
# end query.
# Inputs:  [ 0.  0.  0.]
# Outputs:  [[ 0.52233906]
#  [ 0.47553487]
#  [ 0.66653983]]
# end query.
# Inputs:  [ 0.  0.  1.]
# Outputs:  [[ 0.35082083]
#  [ 0.49679711]
#  [ 0.26769333]]
# end query.
# Inputs:  [ 0.  1.  0.]
# Outputs:  [[ 0.4896211 ]
#  [ 0.51275313]
#  [ 0.59267342]]
# end query.
# Inputs:  [ 0.  1.  1.]
# Outputs:  [[ 0.34591703]
#  [ 0.50388539]
#  [ 0.26027205]]
# end query.
# Inputs:  [ 1.  0.  0.]
# Outputs:  [[ 0.63142224]
#  [ 0.44439849]
#  [ 0.85036299]]
# end query.
# Inputs:  [ 1.  0.  1.]
# Outputs:  [[ 0.40666208]
#  [ 0.49831752]
#  [ 0.37146092]]
# end query.
# Inputs:  [ 1.  1.  0.]
# Outputs:  [[ 0.60935382]
#  [ 0.47485146]
#  [ 0.81855207]]
# end query.
# Inputs:  [ 1.  1.  1.]
# Outputs:  [[ 0.38962677]
#  [ 0.51211551]
#  [ 0.33896699]]

# %%
# calculate the performance score, the fraction of correct answers
scorecard_array = numpy.asarray(scorecard)
print ("performance = ", scorecard_array.sum() / scorecard_array.size)
# Out:
# performance =  0.25
